# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png](attachment:54037340-1f5e-4993-a135-463a1536eb06.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![3-intro.png](attachment:ee57fabd-2715-4863-8e26-b2d387cf8353.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# *Python
# *R
# *SQL

# %% [markdown]
# ![4-dslanguages.png](attachment:50e5ef08-34bb-4136-95a1-1661a19a4e25.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# *Panda
# *Numpy
# *Matplotlib
# *Seaborn

# %% [markdown]
# ![5-dslibraries.png](attachment:0c9cb072-ae22-4a96-ad18-ed2322928071.png)

# %% [markdown]
# | Data Science Tools|
# |----------|
# | Rstudio|
# | JupyterLab|
# | Google Colab|

# %% [markdown]
# ![6-dstools.png](attachment:53c23a31-53d7-4919-a492-ab71846b3c55.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# ![7-introarithmetic.png](attachment:8929d1bf-b413-4da7-9a17-0c73f9b1bb36.png)

# %%
#this a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:dde99759-cfea-4635-81d1-6dd0e1a09c84.png)

# %%
#This will convert 200 minutes to hours by diving by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:1af49a7c-4863-45ee-8310-f949f6933542.png)

# %% [markdown]
# **Objectives:**
# - Python
# - R
# - Java
# - C++

# %% [markdown]
# ![10-objectives.png](attachment:bebfc4c8-ae68-4c38-b3b3-96edde6ee8a6.png)

# %% [markdown]
# ## Author
# Luis

# %% [markdown]
# ![11-authordetails.png](attachment:4214e29d-5ec1-4fae-91bb-aaa7a37a2c69.png)
